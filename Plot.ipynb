# %% [markdown]
# <a href="https://colab.research.google.com/github/YujingYang666777/TaxonomyConstruction/blob/master/Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plot

# %%
train_acc_list = [0.67, 0.69, 0.75, 0.7,0.66,0.68,0.81, 0.71, 0.77,0.77]

# %%
test_acc_list = [0.6885919199215726,0.7300758474794902,0.7274340849285382,0.7545740673855839, 0.7494246942882204,
                 0.762850214127238,0.7742118569733244, 0.7811361642846086,0.780465404261906,0.7824570455600847]

# %%
  import matplotlib.pyplot as plt
  epochs = range(0,10)
  plt.plot(epochs, train_acc_list, 'g', label='SP: Train Accuracy')
  plt.plot(epochs, test_acc_list, 'b', label='Baseline: Train Accuracy')
  plt.title('Train Accuracy vs Epochs')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy_score')
  plt.legend()
  plt.show()

# %%
train_f1_list = [0.45901639344262296, 0.5753424657534247,0.6153846153846154, 0.5945945945945945,0.5405405405405406,
                 0.5428571428571428, 0.6885245901639343, 0.6233766233766234, 0.676056338028169, 0.6567164179104478]

# %%
test_f1_list = [0.69164035437295, 0.7654816873627114, 0.7514281143244336, 0.7787977715152024,0.7505137267795495,
                0.7630751466540204, 0.7788201043225101, 0.7878781817272591, 0.7839808289839769, 0.7858209637599439]

# %%
import matplotlib.pyplot as plt
epochs = range(0,10)
plt.plot(epochs, train_f1_list, 'g', label='Train F1')
plt.plot(epochs, test_f1_list, 'b', label='Test F1')
plt.title('Soft Prompting: F1 vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy_score')
plt.legend()
plt.show()

# %%
import pickle
with open('/content/drive/MyDrive/599/project_data/train_dataset.pkl', 'rb') as handle:
    train_dataset = pickle.load(handle)
    print(len(train_dataset["label"]))
# Out:
# 326244

# %%
train_dataset["label"].count(0)
# Out:
# 217496

# %% [markdown]
# ### baseline

# %%
Training_Acc = [0.6804661541668199,0.7023424185578891, 0.7130675200156937, 0.7189925331960128, 0.722955824474932,
                0.7251688919949486, 0.7272685474675397, 0.7287490344650016, 0.7287827515601819, 0.7310540576991454]

# %%
Train_f1 = [0.4828964860413897,0.5441726632212882 , 0.5627907411213032,0.5719488450925188 , 0.5786686556032072]

# %%
Test_acc = [0.6996600866934856, 0.7049095123751312, 0.7108242118065301, 0.7261670876602114, 0.7282876477375495,
            0.7314788827558965, 0.7341503726572489, 0.7360526397854492, 0.73694660138668, 0.7383083335932059]

# %%
Test_f1 = [0.7136556891271816, 0.7068082293646204, 0.7089179772106601, 0.7504286945894478, 0.7476467691951227,
          0.755526953361599, 0.7618205015971763, 0.7630282215917575, 0.7576285796379657, 0.7617650677088756]

# %%
import matplotlib.pyplot as plt
epochs = range(0,10)
plt.plot(epochs, test_acc_list, 'g', label='SP: Test Accuracy')
plt.plot(epochs, Test_acc, 'b', label='Baseline: Test Accuracy')
plt.title('Test Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
epochs = range(0,10)
plt.plot(epochs, test_f1_list, 'g', label='SP: Test F1')
plt.plot(epochs, Test_f1, 'b', label='Baseline: Test F1')
plt.title('Test F1 Score vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# %% [markdown]
# # Terminatin

# %%
from google.colab import runtime
runtime.unassign()
